# %%
from train_test_utils import LossDistribution

# %%
l = LossDistribution("20230626_distributions/brownian/03.json")
l.plot_learning_curves(log_scale=True)

# %%
l = LossDistribution("20230626_distributions/brownian/04.json")
l.plot_learning_curves(log_scale=True)

# %%
l = LossDistribution("../20230626_distributions/brownian/05.json")
l.plot_learning_curves(log_scale=True)

# %%
l = LossDistribution("../20230626_distributions/brownian/06.json")
l.plot_learning_curves(log_scale=False)
# Out:
# (array([0.20518595, 0.20560816, 0.20393556, 0.20497152, 0.20961412,
#         0.20465396, 0.20555597, 0.20517659, 0.20560613, 0.21374422,
#         0.20646476, 0.20579979, 0.20572497, 0.21818153, 0.21978334,
#         0.21999642, 0.21912468, 0.21838157, 0.21887935, 0.21945061,
#         0.20641394, 0.20611926, 0.20497801, 0.20666997, 0.20551901,
#         0.20389969, 0.21141766, 0.20438952, 0.2041077 , 0.20610396,
#         0.22028297, 0.21274485, 0.20435681, 0.2065858 , 0.20523353,
#         0.20629914, 0.21855902, 0.20475917, 0.20612156, 0.22244412]),
#  array([0.21453562, 0.21265972, 0.20939813, 0.21189931, 0.21099692,
#         0.21078416, 0.21778942, 0.21197736, 0.21008428, 0.20998359,
#         0.21089464, 0.21039609, 0.21239699, 0.20971385, 0.20970606,
#         0.21128   , 0.2115562 , 0.21171093, 0.21109869, 0.20956946,
#         0.2213792 , 0.21147858, 0.21043589, 0.21183986, 0.21416599,
#         0.20977535, 0.21107853, 0.21166853, 0.2095001 , 0.21841078,
# ...

# %%
f, b = l.at_epoch(20)
f.mean(), b.mean()
# Out:
# (0.20957112180596366, 0.2117458256206858)
